# %%
import pandas as pd
import geopandas as gpd

# %%
his_servicio_01_path = '/media/cristian/Alpha/3_PROYECTOS/HACKATONS/TAXIS LIBRES/HIS_SERVICIO_01.csv'
his_servicio_01_df = pd.read_csv(his_servicio_01_path)
his_servicio_01_df
# Out:
# /home/cristian/Documents/predyctiva/env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (18,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               ID  AGENTE  AUTOMOVILASIGNADO_ID  CADUCIDADASIGNACIONSERVICIO  \
# 0       45691435     NaN                   NaN                          180
# 1       45691436     NaN                   NaN                           90
# 2       45691437     NaN                   NaN                          180
# 3       45691438     NaN                   NaN                          180
# 4       45691439     NaN                   NaN                          180
# ...          ...     ...                   ...                          ...
# 844562  46535999     NaN              107879.0                           90
# 844563  46536000     NaN              159745.0                           90
# ...

# %%
his_servicio_02_path = '/media/cristian/Alpha/3_PROYECTOS/HACKATONS/TAXIS LIBRES/HIS_SERVICIO_02.csv'
his_servicio_02_df = pd.read_csv(his_servicio_02_path)
his_servicio_02_df
# Out:
#               ID  AGENTE  AUTOMOVILASIGNADO_ID  CADUCIDADASIGNACIONSERVICIO  \
# 0       46536004     NaN              126004.0                          180
# 1       46536005     NaN              109328.0                          180
# 2       46536006     NaN              174742.0                          180
# 3       46536007     NaN              126044.0                           90
# 4       46536008     NaN              121550.0                          180
# ...          ...     ...                   ...                          ...
# 663240  47199244     NaN              170666.0                          180
# 663241  47199245     NaN              143876.0                          180
# 663242  47199246   354.0              118549.0                           90
# 663243  47199247     NaN              133451.0                          180
# 663244  47199248     NaN               74735.0                           90
#
# ...

# %%
his_servicio_03_path = '/media/cristian/Alpha/3_PROYECTOS/HACKATONS/TAXIS LIBRES/HIS_SERVICIO_03.csv'
his_servicio_03_df = pd.read_csv(his_servicio_03_path)
his_servicio_03_df
# Out:
# /home/cristian/Documents/predyctiva/env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               ID  AGENTE  AUTOMOVILASIGNADO_ID  CADUCIDADASIGNACIONSERVICIO  \
# 0       47199249     NaN                   NaN                          180
# 1       47199250     NaN              123811.0                          180
# 2       47199251     NaN              108687.0                          180
# 3       47199252     NaN                   NaN                          180
# 4       47199253     NaN                   NaN                           90
# ...          ...     ...                   ...                          ...
# 968427  48167676     NaN                   NaN                           90
# 968428  48167677     NaN                   NaN                          180
# ...

# %%
his_servicio_04_path = '/media/cristian/Alpha/3_PROYECTOS/HACKATONS/TAXIS LIBRES/HIS_SERVICIO_04.csv'
his_servicio_04_df = pd.read_csv(his_servicio_04_path)
his_servicio_04_df
# Out:
#               ID  AGENTE  AUTOMOVILASIGNADO_ID  CADUCIDADASIGNACIONSERVICIO  \
# 0       48167681     NaN              135018.0                           90
# 1       48167682     NaN              106826.0                           90
# 2       48167683     NaN              171219.0                          180
# 3       48167684     NaN                   NaN                          180
# 4       48167685     NaN                   NaN                          180
# ...          ...     ...                   ...                          ...
# 987607  49155288     NaN              162520.0                           90
# 987608  49155289     NaN                   NaN                          180
# 987609  49155290     NaN                   NaN                          180
# 987610  49155291     NaN                   NaN                          180
# 987611  49155292     NaN                   NaN                           90
#
# ...

# %%
top_persona_path = '/media/cristian/Alpha/3_PROYECTOS/HACKATONS/TAXIS LIBRES/top_persona.csv'
top_persona_df = pd.read_csv(top_persona_path)
top_persona_df
# Out:
#                   id_persona niv_escolaridad per_fechanaci   per_sexo  \
# 0      100000302713725000000      SECUNDARIA    1989-09-21  MASCULINO
# 1      100005439342914000000      SECUNDARIA    1985-06-02  MASCULINO
# 2      100012975567262000000      SECUNDARIA    1900-01-01        NaN
# 3      100027951170637000000      SECUNDARIA    1983-04-07  MASCULINO
# 4      100039912992801000000      SECUNDARIA    1974-12-11  MASCULINO
# ...                      ...             ...           ...        ...
# 15023  879433764434563000000      SECUNDARIA    1971-03-03  MASCULINO
# 15024  897515644434569000000      SECUNDARIA    1969-05-16  MASCULINO
# 15025  900472224432770000000      SECUNDARIA    1972-04-22  MASCULINO
# 15026  930334754432779000000      SECUNDARIA    1989-03-10  MASCULINO
# 15027  949870604434584000000      SECUNDARIA    1984-03-19        NaN
#
#          est_idestaper        per_fecafilia
# 0      SOLTERO          2021-02-08 12:24:23
# ...

# %%
list(his_servicio_01_df.columns)
# Out:
# ['ID',
#  'AGENTE',
#  'AUTOMOVILASIGNADO_ID',
#  'CADUCIDADASIGNACIONSERVICIO',
#  'CALIFICACIONCONDUCTORASIGNADO',
#  'CALIFICACION_USUARIO',
#  'CONDUCTORASIGNADO_ID',
#  'CONDUCTORESPOSTULADOS',
#  'COSTO',
#  'DELTACADUCIDADASIGNACION',
#  'DIRECCIONCOMPLEMENTARIA',
#  'DIRECCIONDESTINO',
#  'DIRECCIONPRINCIPAL',
#  'ESTADO',
#  'FECHA',
#  'FECHALEGIBLE',
#  'HORALANZAMIENTO',
#  'IDCIUDAD',
#  'IDLLAMADA',
#  'IDSERVICIO',
#  'INDICACIONES',
#  'LATITUD',
#  'LATITUDDESTINO',
#  'LONGITUD',
#  'LONGITUDDESTINO',
#  'MEDIOPAGO',
#  'NUMEROVALE',
#  'ORIGEN',
#  'PLACAAUTOMOVILASIGNADO',
#  'PROMEDIOCONDUCTORASIGNADO',
#  'PROPINA',
#  'TAMANOVEHICULO',
#  'TIPOASIGNACION',
#  'TIPOSERVICIO',
#  'USAPLANILLA',
#  'USUARIO',
#  'USUARIOAPLICACION_ID',
#  'USUARIOTELEFONICO_ID',
#  'IDCONDUCTORASIGNADO',
#  'PAGOEXITOSO',
#  'MOTIVORECHAZO',
#  'DIRECCIONMOSTRAR',
#  'DESCPAGO',
#  'BARRIOORIGEN',
#  'NUMEROCARROS',
#  'ANTERIOR',
#  'RUTA',
#  'CONDUCTOR_CERCANO',
# ...

# %%
len(his_servicio_01_df.columns)
# Out:
# 56

# %%
list(his_servicio_02_df.columns)
# Out:
# ['ID',
#  'AGENTE',
#  'AUTOMOVILASIGNADO_ID',
#  'CADUCIDADASIGNACIONSERVICIO',
#  'CALIFICACIONCONDUCTORASIGNADO',
#  'CALIFICACION_USUARIO',
#  'CONDUCTORASIGNADO_ID',
#  'CONDUCTORESPOSTULADOS',
#  'COSTO',
#  'DELTACADUCIDADASIGNACION',
#  'DIRECCIONCOMPLEMENTARIA',
#  'DIRECCIONDESTINO',
#  'ESTADO',
#  'FECHA',
#  'FECHALEGIBLE',
#  'HORALANZAMIENTO',
#  'IDCIUDAD',
#  'IDLLAMADA',
#  'IDSERVICIO',
#  'INDICACIONES',
#  'LATITUD',
#  'LATITUDDESTINO',
#  'LONGITUD',
#  'LONGITUDDESTINO',
#  'MEDIOPAGO',
#  'NUMEROVALE',
#  'ORIGEN',
#  'PLACAAUTOMOVILASIGNADO',
#  'PROMEDIOCONDUCTORASIGNADO',
#  'PROPINA',
#  'TAMANOVEHICULO',
#  'TIPOASIGNACION',
#  'TIPOSERVICIO',
#  'USAPLANILLA',
#  'USUARIO',
#  'USUARIOAPLICACION_ID',
#  'USUARIOTELEFONICO_ID',
#  'IDCONDUCTORASIGNADO',
#  'DESCPAGO',
#  'BARRIOORIGEN',
#  'NUMEROCARROS',
#  'ANTERIOR',
#  'RUTA',
#  'CONDUCTOR_CERCANO',
#  'RECORRIDO_METROS',
#  'DISTANCIA',
#  'RECORRIDO_DISTANCIA',
#  'CALC_TARIFA',
# ...

# %%
len(his_servicio_02_df.columns)
# Out:
# 52

# %%
list(his_servicio_03_df.columns)
# Out:
# ['ID',
#  'AGENTE',
#  'AUTOMOVILASIGNADO_ID',
#  'CADUCIDADASIGNACIONSERVICIO',
#  'CALIFICACIONCONDUCTORASIGNADO',
#  'CALIFICACION_USUARIO',
#  'CONDUCTORASIGNADO_ID',
#  'CONDUCTORESPOSTULADOS',
#  'COSTO',
#  'DELTACADUCIDADASIGNACION',
#  'DIRECCIONCOMPLEMENTARIA',
#  'DIRECCIONDESTINO',
#  'DIRECCIONPRINCIPAL',
#  'ESTADO',
#  'FECHA',
#  'FECHALEGIBLE',
#  'HORALANZAMIENTO',
#  'IDCIUDAD',
#  'IDLLAMADA',
#  'IDSERVICIO',
#  'INDICACIONES',
#  'LATITUD',
#  'LATITUDDESTINO',
#  'LONGITUD',
#  'LONGITUDDESTINO',
#  'MEDIOPAGO',
#  'NUMEROVALE',
#  'ORIGEN',
#  'PLACAAUTOMOVILASIGNADO',
#  'PROMEDIOCONDUCTORASIGNADO',
#  'PROPINA',
#  'TAMANOVEHICULO',
#  'TIPOASIGNACION',
#  'TIPOSERVICIO',
#  'USAPLANILLA',
#  'USUARIO',
#  'USUARIOAPLICACION_ID',
#  'USUARIOTELEFONICO_ID',
#  'IDCONDUCTORASIGNADO',
#  'DESCPAGO',
#  'BARRIOORIGEN',
#  'NUMEROCARROS',
#  'ANTERIOR',
#  'RUTA',
#  'CONDUCTOR_CERCANO',
#  'RECORRIDO_METROS',
#  'DISTANCIA',
#  'RECORRIDO_DISTANCIA',
# ...

# %%
len(his_servicio_03_df.columns)
# Out:
# 53

# %%
list(his_servicio_04_df.columns)
# Out:
# ['ID',
#  'AGENTE',
#  'AUTOMOVILASIGNADO_ID',
#  'CADUCIDADASIGNACIONSERVICIO',
#  'CALIFICACIONCONDUCTORASIGNADO',
#  'CALIFICACION_USUARIO',
#  'CONDUCTORASIGNADO_ID',
#  'CONDUCTORESPOSTULADOS',
#  'COSTO',
#  'DELTACADUCIDADASIGNACION',
#  'DIRECCIONCOMPLEMENTARIA',
#  'DIRECCIONDESTINO',
#  'DIRECCIONPRINCIPAL',
#  'ESTADO',
#  'FECHA',
#  'FECHALEGIBLE',
#  'HORALANZAMIENTO',
#  'IDCIUDAD',
#  'IDLLAMADA',
#  'IDSERVICIO',
#  'INDICACIONES',
#  'LATITUD',
#  'LATITUDDESTINO',
#  'LONGITUD',
#  'LONGITUDDESTINO',
#  'MEDIOPAGO',
#  'NUMEROVALE',
#  'ORIGEN',
#  'PLACAAUTOMOVILASIGNADO',
#  'PROMEDIOCONDUCTORASIGNADO',
#  'PROPINA',
#  'TAMANOVEHICULO',
#  'TIPOASIGNACION',
#  'TIPOSERVICIO',
#  'USAPLANILLA',
#  'USUARIO',
#  'USUARIOAPLICACION_ID',
#  'USUARIOTELEFONICO_ID',
#  'IDCONDUCTORASIGNADO',
#  'DESCPAGO',
#  'BARRIOORIGEN',
#  'NUMEROCARROS',
#  'ANTERIOR',
#  'RUTA',
#  'CONDUCTOR_CERCANO',
#  'RECORRIDO_METROS',
#  'DISTANCIA',
#  'RECORRIDO_DISTANCIA',
# ...

# %%
len(his_servicio_04_df.columns)
# Out:
# 53

# %%
list(set(list(his_servicio_01_df.columns)).difference(set(list(his_servicio_02_df.columns))))
# Out:
# ['DIRECCIONMOSTRAR', 'DIRECCIONPRINCIPAL', 'PAGOEXITOSO', 'MOTIVORECHAZO']

# %%
list(set(list(his_servicio_01_df.columns)).difference(set(list(his_servicio_03_df.columns))))
# Out:
# ['DIRECCIONMOSTRAR', 'PAGOEXITOSO', 'MOTIVORECHAZO']

# %%
list(set(list(his_servicio_01_df.columns)).difference(set(list(his_servicio_04_df.columns))))
# Out:
# ['DIRECCIONMOSTRAR', 'PAGOEXITOSO', 'MOTIVORECHAZO']

# %%
his_servicio_df = pd.DataFrame()
his_servicio_df = his_servicio_01_df.append(his_servicio_02_df, ignore_index=True)
his_servicio_df = his_servicio_df.append(his_servicio_03_df, ignore_index=True)
his_servicio_df = his_servicio_df.append(his_servicio_04_df, ignore_index=True)

# %%
his_servicio_df
# Out:
#                ID  AGENTE  AUTOMOVILASIGNADO_ID  CADUCIDADASIGNACIONSERVICIO  \
# 0        45691435     NaN                   NaN                          180
# 1        45691436     NaN                   NaN                           90
# 2        45691437     NaN                   NaN                          180
# 3        45691438     NaN                   NaN                          180
# 4        45691439     NaN                   NaN                          180
# ...           ...     ...                   ...                          ...
# 3463851  49155288     NaN              162520.0                           90
# 3463852  49155289     NaN                   NaN                          180
# 3463853  49155290     NaN                   NaN                          180
# 3463854  49155291     NaN                   NaN                          180
# 3463855  49155292     NaN                   NaN                           90
#
# ...

# %%
list(his_servicio_df.columns)
# Out:
# ['ID',
#  'AGENTE',
#  'AUTOMOVILASIGNADO_ID',
#  'CADUCIDADASIGNACIONSERVICIO',
#  'CALIFICACIONCONDUCTORASIGNADO',
#  'CALIFICACION_USUARIO',
#  'CONDUCTORASIGNADO_ID',
#  'CONDUCTORESPOSTULADOS',
#  'COSTO',
#  'DELTACADUCIDADASIGNACION',
#  'DIRECCIONCOMPLEMENTARIA',
#  'DIRECCIONDESTINO',
#  'DIRECCIONPRINCIPAL',
#  'ESTADO',
#  'FECHA',
#  'FECHALEGIBLE',
#  'HORALANZAMIENTO',
#  'IDCIUDAD',
#  'IDLLAMADA',
#  'IDSERVICIO',
#  'INDICACIONES',
#  'LATITUD',
#  'LATITUDDESTINO',
#  'LONGITUD',
#  'LONGITUDDESTINO',
#  'MEDIOPAGO',
#  'NUMEROVALE',
#  'ORIGEN',
#  'PLACAAUTOMOVILASIGNADO',
#  'PROMEDIOCONDUCTORASIGNADO',
#  'PROPINA',
#  'TAMANOVEHICULO',
#  'TIPOASIGNACION',
#  'TIPOSERVICIO',
#  'USAPLANILLA',
#  'USUARIO',
#  'USUARIOAPLICACION_ID',
#  'USUARIOTELEFONICO_ID',
#  'IDCONDUCTORASIGNADO',
#  'PAGOEXITOSO',
#  'MOTIVORECHAZO',
#  'DIRECCIONMOSTRAR',
#  'DESCPAGO',
#  'BARRIOORIGEN',
#  'NUMEROCARROS',
#  'ANTERIOR',
#  'RUTA',
#  'CONDUCTOR_CERCANO',
# ...

# %%
for column in list(his_servicio_df.columns):
    print('*'*30)
    print(column)
    print('-'*30)
    print(his_servicio_df[column].describe())
    
    print('*'*30)
# Out:
# ******************************
# ID
# ------------------------------
# count    3.463856e+06
# mean     4.742336e+07
# std      9.999297e+05
# min      4.569144e+07
# 25%      4.655740e+07
# 50%      4.742336e+07
# 75%      4.828933e+07
# max      4.915529e+07
# Name: ID, dtype: float64
# ******************************
# ******************************
# AGENTE
# ------------------------------
# count    173708.000000
# mean        387.831010
# std         181.011602
# min           0.000000
# 25%         174.000000
# 50%         395.000000
# 75%         545.000000
# max         673.000000
# Name: AGENTE, dtype: float64
# ******************************
# ******************************
# AUTOMOVILASIGNADO_ID
# ------------------------------
# count    2.581739e+06
# mean     1.361874e+05
# std      3.580726e+04
# min      1.500000e+01
# 25%      1.210110e+05
# 50%      1.425530e+05
# 75%      1.626860e+05
# max      1.764130e+05
# Name: AUTOMOVILASIGNADO_ID, dtype: float64
# ...

# %%
his_servicio_df = his_servicio_df.drop(['CONDUCTORESPOSTULADOS','HORALANZAMIENTO','IDSERVICIO','USAPLANILLA','USUARIOAPLICACION_ID','NUMEROCARROS','ANTERIOR','RUTA','CONDUCTOR_CERCANO','RECORRIDO_METROS','DISTANCIA','RECORRIDO_DISTANCIA','CALC_TARIFA','PRELIQUIDACION','TIEMPO','NUMERO_PASAJEROS','COSTO_INTERRUMPIDO'], axis = 1)

# %%
his_servicio_df
# Out:
#                ID  AGENTE  AUTOMOVILASIGNADO_ID  CADUCIDADASIGNACIONSERVICIO  \
# 0        45691435     NaN                   NaN                          180
# 1        45691436     NaN                   NaN                           90
# 2        45691437     NaN                   NaN                          180
# 3        45691438     NaN                   NaN                          180
# 4        45691439     NaN                   NaN                          180
# ...           ...     ...                   ...                          ...
# 3463851  49155288     NaN              162520.0                           90
# 3463852  49155289     NaN                   NaN                          180
# 3463853  49155290     NaN                   NaN                          180
# 3463854  49155291     NaN                   NaN                          180
# 3463855  49155292     NaN                   NaN                           90
#
# ...

# %%
file_name = '/media/cristian/Alpha/3_PROYECTOS/HACKATONS/TAXIS LIBRES/his_servicios.csv'
his_servicio_df.to_csv(file_name, encoding='utf-8', index= False)

# %%
top_persona_df
# Out:
#                   id_persona niv_escolaridad per_fechanaci   per_sexo  \
# 0      100000302713725000000      SECUNDARIA    1989-09-21  MASCULINO
# 1      100005439342914000000      SECUNDARIA    1985-06-02  MASCULINO
# 2      100012975567262000000      SECUNDARIA    1900-01-01        NaN
# 3      100027951170637000000      SECUNDARIA    1983-04-07  MASCULINO
# 4      100039912992801000000      SECUNDARIA    1974-12-11  MASCULINO
# ...                      ...             ...           ...        ...
# 15023  879433764434563000000      SECUNDARIA    1971-03-03  MASCULINO
# 15024  897515644434569000000      SECUNDARIA    1969-05-16  MASCULINO
# 15025  900472224432770000000      SECUNDARIA    1972-04-22  MASCULINO
# 15026  930334754432779000000      SECUNDARIA    1989-03-10  MASCULINO
# 15027  949870604434584000000      SECUNDARIA    1984-03-19        NaN
#
#          est_idestaper        per_fecafilia
# 0      SOLTERO          2021-02-08 12:24:23
# ...

# %%
list(top_persona_df.columns)
# Out:
# ['id_persona',
#  'niv_escolaridad',
#  'per_fechanaci',
#  'per_sexo',
#  'est_idestaper',
#  'per_fecafilia']

# %%
for column in list(top_persona_df.columns):
    print('*'*30)
    print(column)
    print('-'*30)
    print(top_persona_df[column].describe())
    print('*'*30)
# Out:
# ******************************
# id_persona
# ------------------------------
# count                     15028
# unique                    15028
# top       155113144845167000000
# freq                          1
# Name: id_persona, dtype: object
# ******************************
# ******************************
# niv_escolaridad
# ------------------------------
# count          15028
# unique             8
# top       SECUNDARIA
# freq           13228
# Name: niv_escolaridad, dtype: object
# ******************************
# ******************************
# per_fechanaci
# ------------------------------
# count          15028
# unique          8590
# top       1990-01-01
# freq            2445
# Name: per_fechanaci, dtype: object
# ******************************
# ******************************
# per_sexo
# ------------------------------
# count         12218
# unique            4
# top       MASCULINO
# freq          11505
# Name: per_sexo, dtype: object
# ...
